# %% [markdown]
# # 验证在终端配置的MMSegmentation环境是否正确

# %% [markdown]
# Jupyter Notebook 代码文件（.ipynb），在页面右上角点击当前的内核名称（通常写着 Python 3 (ipykernel)），在弹出的下拉菜单中，选择你刚刚创建的 Python (mmseg_env)。

# %%
import torch
import mmseg
print(f"PyTorch version: {torch.__version__}")
print(f"MMSegmentation version: {mmseg.__version__}")
# Out:
# PyTorch version: 1.10.1+cu113
# MMSegmentation version: 1.1.1

# %% [markdown]
# # 在 AutoDL 中保存这个环境，方便以后使用

# %% [markdown]
# 使用“保存自定义镜像”功能：
#
# 1.当你在这个机器上把所有的环境都配置好，代码也能跑通之后。
#
# 2.回到 AutoDL 的**“控制台” -> “容器实例”**页面。
#
# 3.找到你当前正在运行的这台机器，点击右侧的**“更多” -> “保存镜像”**。
#
# 4.给这个镜像起个名字（比如：我的街景语义分割环境_mmcv2.0）。Jupyter Notebook 代码文件（.ipynb），在页面右上角点击当前的内核名称（通常写着 Python 3 (ipykernel)），在弹出的下拉菜单中，选择你刚刚创建的 Python (mmseg_env)。
